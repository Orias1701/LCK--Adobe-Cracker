# %%
from _Helpers import mergeData

mergeData.mergeJsons('HNMU/HNMU_Chunks_Segment_1.json', 'HNMU/HNMU_Chunks_Segment_2.json', 'HNMU_merged/HNMU_merged_Chunks_Segment.json')

# %%
from _Helpers import convertExcel

FOLDER_DATA = 'HNMU'
NEEDED_DATA = 'Chunks'
convertExcel.mainProcess(FOLDER_DATA, NEEDED_DATA)
# Out:
# ✅ Đã đọc Data thành công.
#    -> Đang xử lý cột 'Content' theo kiểu ARRAY (gộp dòng)...
# ✅ Thành công! File Excel đã được tạo tại: HNMU/HNMU_Chunks_Sheet.xlsx
