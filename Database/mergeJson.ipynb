# %%
from _Helpers import mergeData

mergeData.merge_jsons('HNMU/HNMU_Chunks_Segment_1.json', 'HNMU/HNMU_Chunks_Segment_1.json', 'HNMU/HNMU_Chunks_Segment.json')
# Out:
# Đã gộp thành công vào file: HNMU/HNMU_Chunks_Segment.json
